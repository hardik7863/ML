# %% [markdown]
# ## **Work Flow**

# %% [markdown]
# ![Screenshot from 2025-01-06 17-07-42.png](<attachment:Screenshot from 2025-01-06 17-07-42.png>)

# %% [markdown]
# ![Screenshot from 2025-01-06 17-10-02.png](<attachment:Screenshot from 2025-01-06 17-10-02.png>)

# %% [markdown]
# ## **Sequential Model**

# %% [markdown]
# ![Screenshot from 2025-01-06 17-14-05.png](<attachment:Screenshot from 2025-01-06 17-14-05.png>)

# %% [markdown]
# There are around 20 trainable parameters (add weights and bias at hidden layer and output layer). in order to create the hidden layer there is a library in keras called dense we will use that

# %% [markdown]
# ![Screenshot from 2025-01-06 17-21-08.png](<attachment:Screenshot from 2025-01-06 17-21-08.png>)

# %% [markdown]
# ## **X_train.shape[1]**

# %% [markdown]
# ![Screenshot from 2025-01-06 17-27-30.png](<attachment:Screenshot from 2025-01-06 17-27-30.png>)

# %% [markdown]
# ## **Neurons in Hidden Layer**

# %% [markdown]
# ![Screenshot from 2025-01-06 17-31-07.png](<attachment:Screenshot from 2025-01-06 17-31-07.png>)

# %% [markdown]
# In 1 st hidden layer we have used 64 neurons whereas we have used 32 neurons then 1 neurons
